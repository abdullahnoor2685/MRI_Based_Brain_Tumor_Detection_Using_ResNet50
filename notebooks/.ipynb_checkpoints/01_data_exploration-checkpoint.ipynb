# %% [markdown]
# <h1 style="text-align:center">MRI-Based Brain Tumor Classification
# Using Transfer Learning with Explainable
# AI and Automated Diagnostic Reporting</h1>

# %% [markdown]
# ## Setup and Imports

# %%
import os
import random
import numpy as np
import pandas as pd
from pathlib import Path
from PIL import Image

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Project & Dataset Path

# %%
PROJECT_ROOT = Path().resolve().parent
DATASET_PATH = PROJECT_ROOT / "data" / "raw"

classes = ["glioma", "meningioma", "pituitary", "no_tumor"]

print("Dataset Path:", DATASET_PATH)
# Out:
# Dataset Path: C:\Users\itxab\Downloads\AI\Brain_Tumor_Detection_Using_Deep_Learning\data\raw

# %% [markdown]
# ## Build Dataset Manifest

# %%
import os
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent
DATASET_PATH = PROJECT_ROOT / "data" / "raw"

classes = ["glioma", "meningioma", "pituitary", "no_tumor"]

data = []

for label in classes:
    folder = DATASET_PATH / label

    for img_name in os.listdir(folder):
        img_path = folder / img_name
        data.append([str(img_path), label])

df = pd.DataFrame(data, columns=["image_path", "label"])

print(df.head())
print("\nClass Distribution:")
print(df["label"].value_counts())
# Out:
#                                           image_path   label
# 0  C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...  glioma
# 1  C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...  glioma
# 2  C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...  glioma
# 3  C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...  glioma
# 4  C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...  glioma
#
# Class Distribution:
# label
# no_tumor      1595
# pituitary     1457
# meningioma    1339
# glioma        1321
# Name: count, dtype: int64

# %% [markdown]
# ## Save data distribution to CSV

# %%
df.to_csv(PROJECT_ROOT / "data" / "dataset_manifest.csv", index=False)

# %% [markdown]
# ## Class Distribution Plot

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))

df["label"].value_counts().plot(kind="bar")
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Random Image Visualization (Per Class)

# %%
plt.figure(figsize=(12, 8))

for i, cls in enumerate(classes):
    class_images = df[df["label"] == cls]["image_path"].values
    img_path = random.choice(class_images)

    img = Image.open(img_path)

    plt.subplot(2, 2, i + 1)
    plt.imshow(img, cmap="gray")
    plt.title(cls)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Multiple Samples per Class

# %%
import matplotlib.pyplot as plt
from PIL import Image
import random
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent
DATASET_PATH = PROJECT_ROOT / "data" / "raw"

classes = ["glioma", "meningioma", "pituitary", "no_tumor"]

fig, axes = plt.subplots(len(classes), 3, figsize=(12, 12))

for i, cls in enumerate(classes):

    class_folder = DATASET_PATH / cls
    images = os.listdir(class_folder)

    sample_images = random.sample(images, 3)

    for j, img_name in enumerate(sample_images):

        img_path = class_folder / img_name
        img = Image.open(img_path)

        axes[i, j].imshow(img, cmap="gray")
        axes[i, j].axis("off")

        if j == 1:
            axes[i, j].set_title(cls)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Corrupted Image Detection

# %%
corrupted = []

for path in df["image_path"]:
    try:
        img = Image.open(path)
        img.verify()
    except:
        corrupted.append(path)

print("Corrupted Images:", len(corrupted))
# Out:
# Corrupted Images: 14

# %%
df_clean = df[~df["image_path"].isin(corrupted)].reset_index(drop=True)

print("Original size:", len(df))
print("Cleaned size:", len(df_clean))
# Out:
# Original size: 5712
# Cleaned size: 5698

# %%
corrupt_df = pd.DataFrame(corrupted, columns=["corrupted_image_path"])
corrupt_df.to_csv(PROJECT_ROOT / "reports" / "corrupted_images.csv", index=False)

# %%
print(df_clean["label"].value_counts())
# Out:
# label
# no_tumor      1593
# pituitary     1445
# meningioma    1339
# glioma        1321
# Name: count, dtype: int64

# %% [markdown]
# ## Image Shape / Resolution Analysis

# %%
from PIL import Image
import numpy as np

shapes = []

for path in df["image_path"].sample(200):
    img = Image.open(path)
    shapes.append(np.array(img).shape)

set(shapes)
# Out:
# {(168, 300, 3),
#  (192, 192, 3),
#  (198, 150, 3),
#  (201, 173, 3),
#  (211, 219, 3),
#  (217, 232, 3),
#  (221, 228, 3),
#  (222, 227, 3),
#  (225, 225, 3),
#  (231, 218, 3),
#  (236, 200, 3),
#  (236, 212, 3),
#  (236, 236, 3),
#  (238, 212, 3),
#  (242, 208, 3),
#  (244, 206, 3),
#  (245, 206, 3),
#  (249, 201, 3),
#  (250, 201, 3),
#  (251, 201, 3),
#  (252, 200, 3),
#  (256, 256, 3),
#  (262, 227, 3),
#  (274, 230, 3),
#  (275, 220, 3),
#  (307, 257, 3),
#  (314, 329, 3),
#  (340, 339, 3),
#  (356, 286, 3),
#  (357, 236, 3),
#  (361, 642, 3),
#  (394, 295, 3),
#  (400, 393, 3),
#  (417, 428, 3),
#  (442, 400, 3),
#  (442, 442, 3),
#  (443, 354, 3),
#  (444, 468, 3),
#  (454, 442, 3),
#  (480, 853, 3),
#  (512, 512),
#  (512, 512, 3),
#  (540, 504, 3),
#  (613, 605, 3),
#  (630, 630, 3),
#  (664, 550, 3),
#  (903, 721, 3)}

# %%
df = df_clean
df
# Out:
#                                              image_path     label
# 0     C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...    glioma
# 1     C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...    glioma
# 2     C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...    glioma
# 3     C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...    glioma
# 4     C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...    glioma
# ...                                                 ...       ...
# 5693  C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...  no_tumor
# 5694  C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...  no_tumor
# 5695  C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...  no_tumor
# 5696  C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...  no_tumor
# 5697  C:\Users\itxab\Downloads\AI\Brain_Tumor_Detect...  no_tumor
#
# [5698 rows x 2 columns]

# %% [markdown]
# ## Pixel Intensity Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

sample_df = df.sample(5)

plt.figure(figsize=(12, 8))

for i, row in enumerate(sample_df.itertuples()):
    
    img = Image.open(row.image_path).convert("L")
    arr = np.array(img)

    plt.subplot(2, 3, i + 1)
    
    plt.hist(arr.ravel(), bins=50)

    plt.title(f"Tumor Type: {row.label}")

    plt.xlabel("Pixel Intensity")
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Class-wise Mean Image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def mean_image(class_name):
    imgs = df[df["label"] == class_name]["image_path"].sample(50)

    acc = None

    for p in imgs:
        img = cv2.imread(p, 0)
        img = cv2.resize(img, (224,224))

        if acc is None:
            acc = img.astype(np.float32)
        else:
            acc += img

    return acc / len(imgs)

plt.figure(figsize=(10,5))

for i, c in enumerate(df["label"].unique()):
    plt.subplot(1, 4, i+1)
    plt.imshow(mean_image(c), cmap="gray")
    plt.title(f"{c}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Brightness / Intensity Statistics

# %%
def brightness(path):
    img = Image.open(path).convert("L")
    return np.array(img).mean()

df["brightness"] = df["image_path"].apply(brightness)

df.groupby("label")["brightness"].describe()
# Out:
#              count       mean        std        min        25%        50%  \
# label
# glioma      1321.0  32.803638   8.583266  13.748398  26.088947  31.649597
# meningioma  1339.0  43.533933  14.301440  18.292336  34.993952  40.856247
# no_tumor    1593.0  60.785375  21.234523   9.777208  44.189967  57.078887
# pituitary   1445.0  49.228593   8.223847  24.695900  44.033867  49.721127
#
#                   75%         max
# label
# glioma      38.722229   68.510426
# meningioma  46.910473  137.769070
# no_tumor    73.807634  125.152009
# pituitary   54.210136  102.333716

# %%
import cv2
import numpy as np

def mean_image(class_name):
    imgs = df[df["label"] == class_name]["image_path"].sample(50)

    acc = None

    for p in imgs:
        img = cv2.imread(p, 0)
        img = cv2.resize(img, (224,224))

        if acc is None:
            acc = img.astype(np.float32)
        else:
            acc += img

    acc /= len(imgs)
    return acc

classes = df["label"].unique()

plt.figure(figsize=(15,5))

for i, c in enumerate(classes):
    plt.subplot(1, len(classes), i+1)
    plt.imshow(mean_image(c), cmap="gray")
    plt.title(c)
    plt.axis("off")

plt.show()
